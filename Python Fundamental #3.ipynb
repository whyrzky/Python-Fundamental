# %% [markdown]
# <a href="https://colab.research.google.com/github/whyrzky/Python-Fundamental/blob/main/Python%20Fundamental%20%233.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Quiz 1
# ![image.png](data:image/png;base64,...)

# %%
#Answer

nik_karyawan = ['AA28AA9008898569','AA32AA9008666521','AA39AA9008622527','AA42AA9008655524','AA44AA9008655525','AA49AA9008655526','AA21AA9008767589','AA55AA9008622591']

for i in nik_karyawan:
  tmp=int(i.split('AA')[1])
  if tmp %2==0:
    print(i)
# Out:
# AA28AA9008898569
# AA32AA9008666521
# AA42AA9008655524
# AA44AA9008655525

# %% [markdown]
# #Quiz 2
# ![image.png](data:image/png;base64,...)

# %%
#Answer
biodata = {'full_name' : ['Arif','Dynasti','Rivan','Cepi'],
           'last_name' : ['Pras', 'Septiani','Nul Mulki','Hardi'],
           'umur':['23','22','21','26'],
           'hobi':['Futsal','Sepak Bola',['Tenis','Voli'],['Memancing','Sepak Bola']]}

f_rivan = biodata['full_name'][2]
l_rivan = biodata['last_name'][2]
u_rivan = biodata['umur'][2]
h_rivan = biodata['hobi'][2][1]

rivan = print('Halo namaku' + ' ' + f_rivan + ' ' + l_rivan + ', umurku' + ' ' + u_rivan + ' ' + 'tahun, hobiku' + ' ' + h_rivan)
# Out:
# Halo namaku Rivan Nul Mulki, umurku 21 tahun, hobiku Voli

# %% [markdown]
# #Quiz 3
# ![image.png](data:image/png;base64,...)

# %%
#Answer
buah = ['Mangga','Pisang','Jeruk','Apel','Melon','Anggur','Semangka','Alpukat','Arbei','Plum','Pepaya']

buah_ap = [ x for x in buah if x[0] == 'A' or x[0] == 'P' ]
buah_ap
# Out:
# ['Pisang', 'Apel', 'Anggur', 'Alpukat', 'Arbei', 'Plum', 'Pepaya']

# %% [markdown]
# #Quiz 4
# ![image.png](data:image/png;base64,...)

# %%
#Answer
h1 = {2,3,4,5,7,9,12}
h2 = {2,3,4,14,15,16,17}

h1.intersection(h2)
# Out:
# {2, 3, 4}
