# %% [markdown]
# <a href="https://colab.research.google.com/github/whyrzky/Python-Fundamental/blob/main/Python%20Fundamental%231.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #1.) Assigment
# ![image.png](data:image/png;base64,...)

# %%
#Answer 1
import math
x = [1, 1]
y = [0.5, 1]
distance_formula = math.sqrt(((x[1]-x[0])**2)+((y[1]-y[0])**2))

print(distance_formula)
# Out:
# 0.5

# %%
#Answer 2
import math
x = [1, 5]
y = [1, 4]
distance_formula = math.sqrt(((x[1]-x[0])**2)+((y[1]-y[0])**2))

print(distance_formula)
# Out:
# 5.0

# %% [markdown]
# #2.) Assigment
# ![image.png](data:image/png;base64,...)

# %%
#Answer
plat_nomor1= 'D 1134 XE','D 2243 PP','D 9921 QW','D 9912 PO','D 5512 LK'
plat_nomor2= 'B 2313 LO','BK 2232 MF','B 1432 OQ','G 2232 KL',' G 9001 ML','AA 9493 LU'
plat_gabungan = plat_nomor1+plat_nomor2
plat_bandung = [ i for i in plat_gabungan if i[0] == 'D']
plat_bandung
# Out:
# ['D 1134 XE', 'D 2243 PP', 'D 9921 QW', 'D 9912 PO', 'D 5512 LK']

# %% [markdown]
# #3.) Assigment
# ![image.png](data:image/png;base64,...)

# %%
#Answer
biodata = {'full_name' : ['Arif','Dynasti','Rivan','Cepi'],
           'last_name' : ['Pras', 'Septiani','Nul Mulki','Hardi'],
           'umur':['23','22','21','26'],
           'hobi':['Futsal','Sepak Bola','Tenis','Memancing']}

for a,b,c,d in zip(biodata['full_name'], biodata['last_name'],biodata['umur'],biodata['hobi']):
  panggil = 'Halo namaku' + ' ' + a +' ' + b + ', umurku' + ' ' +c + 'tahun, dan hobiku' + ' ' + d
  print(panggil)
# Out:
# Halo namaku Arif Pras, umurku 23tahun, dan hobiku Futsal
# Halo namaku Dynasti Septiani, umurku 22tahun, dan hobiku Sepak Bola
# Halo namaku Rivan Nul Mulki, umurku 21tahun, dan hobiku Tenis
# Halo namaku Cepi Hardi, umurku 26tahun, dan hobiku Memancing

# %% [markdown]
# #4.) Assigment
# ![image.png](data:image/png;base64,...)

# %%
#Answer

mytuple = ("Rivan41324", "Ranuq42342", "Ria412", "Budi4544")
mytuple = list(mytuple)
mylist2 = ["Rivan", "Ranu", "Ria", "Budi"]

result = mytuple + mylist2
result
# Out:
# ['Rivan41324',
#  'Ranuq42342',
#  'Ria412',
#  'Budi4544',
#  'Rivan',
#  'Ranu',
#  'Ria',
#  'Budi']

# %% [markdown]
# #5.) Assigment
# ![image.png](data:image/png;base64,...)

# %%
#Answer
x=[[1],[2,3],[2,2,3,4],[3,5],[1,2],[9,9],[10,10,10],[20],[19,19],[1,2,3,4,3],[8,8,8]]
x1 = list(x)

new_list = [ i for i in x1 if len(i) == 2]
new_list
# Out:
# [[2, 3], [3, 5], [1, 2], [9, 9], [19, 19]]
